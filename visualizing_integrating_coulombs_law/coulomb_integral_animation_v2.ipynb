# %%
from __future__ import division

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d
from matplotlib.tri import Triangulation, UniformTriRefiner,\
    CubicTriInterpolator
from mpl_toolkits.mplot3d.art3d import Poly3DCollection as P3D
import numpy as np
import time
from numpy import *
from matplotlib import rc
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=False)

# %%
# %pylab qt4
plt.ion()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['rc']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

# %%
def sph2cart(rho, theta, phi):
    x = rho * sin(theta) * cos(phi)
    y = rho * sin(theta) * sin(phi)
    z = rho * cos(theta)
    return x, y, z

def pol2cart(rho, theta):
    x = rho * cos(theta)
    y = rho * sin(theta)
    return x, y

# %%
def polVolDiffelVerts(r, theta, z, dr, dtheta, dz, ds=None ):
    if ds == None or ds <= 0:
        ds = dr/2
        
    front, back, top, bottom, inside, outside = (True,)*6
    polys = []
    if r <= dr/2:
        r0 = 0
        inside = False
    
    if dtheta >= 2*np.pi:
        dtheta = 2*np.pi
        front = False
        back = False
        
    if front:
        R = [r-dr/2, r+dr/2, r+dr/2, r-dr/2]
        THETA = [theta-dtheta/2]*4
        Z = [z-dz/2, z-dz/2, z+dz/2, z+dz/2]
        X, Y = pol2cart(R, THETA)
        polys.append(zip(X,Y,Z))
        
    if back:
        R = [r-dr/2, r+dr/2, r+dr/2, r-dr/2]
        THETA = [theta+dtheta/2]*4
        Z = [z-dz/2, z-dz/2, z+dz/2, z+dz/2]
        X, Y = pol2cart(R, THETA)
        polys.append(zip(X,Y,Z))
        
    if inside:
        nRectInside = np.max([np.ceil((r-dr/2)*dtheta/ds),2])
        dtheta_ = dtheta / nRectInside
        for theta_ in np.linspace(theta-dtheta/2, theta+dtheta/2, nRectInside, endpoint=False):
            R = [r-dr/2]*4
            THETA = [theta_, theta_+dtheta_, theta_+dtheta_, theta_]
            Z = [z-dz/2, z-dz/2, z+dz/2, z+dz/2]
            X, Y = pol2cart(R, THETA)
            polys.append(zip(X,Y,Z))
            
    if outside:
        nRectOutside = np.max([np.ceil((r+dr/2)*dtheta/ds),2])
        dtheta_ = dtheta / nRectOutside
        for theta_ in np.linspace(theta-dtheta/2, theta+dtheta/2, nRectOutside, endpoint=False):
            R = [r+dr/2]*4
            THETA = [theta_, theta_+dtheta_, theta_+dtheta_, theta_]
            Z = [z-dz/2, z-dz/2, z+dz/2, z+dz/2]
            X, Y = pol2cart(R, THETA)
            polys.append(zip(X,Y,Z))
    
    if top:
        R = []
        THETA = []
        Z = []
        if inside:
            for theta_ in np.linspace(theta+dtheta/2, theta-dtheta/2, nRectInside+1, endpoint=True):
                R.append(r-dr/2)
                THETA.append(theta_)
                Z.append(z+dz/2)
            #if dtheta >= 2*np.pi:
            #    R.pop()
            #    THETA.pop()
            #    Z.pop()
        elif front:
            R.append(0)
            THETA.append(0)
            Z.append(z+dz/2)

        #-- There's *always* an outside!
        for theta_ in np.linspace(theta-dtheta/2, theta+dtheta/2, nRectOutside+1, endpoint=True):
            R.append(r+dr/2)
            THETA.append(theta_)
            Z.append(z+dz/2)

        X, Y = pol2cart(R, THETA)
        polys.append(zip(X,Y,Z))

    if bottom:
        R = []
        THETA = []
        Z = []
        if inside:
            for theta_ in np.linspace(theta+dtheta/2, theta-dtheta/2, nRectInside+1, endpoint=True):
                R.append(r-dr/2)
                THETA.append(theta_)
                Z.append(z-dz/2)
            #if dtheta >= 2*np.pi:
            #    R.pop()
            #    THETA.pop()
            #    Z.pop()

        elif front:
            R.append(0)
            THETA.append(0)
            Z.append(z-dz/2)

        #-- There's *always* an outside!
        for theta_ in np.linspace(theta-dtheta/2, theta+dtheta/2, nRectOutside+1, endpoint=True):
            R.append(r+dr/2)
            THETA.append(theta_)
            Z.append(z-dz/2)

        X, Y = pol2cart(R, THETA)
        polys.append(zip(X,Y,Z))
        
    return polys

# %%
R = 10
Z = 30

#PERSP = "XSIDE"
PERSP = "YSIDE"
#PERSP = "ISO"

plt.close(1)
if PERSP == "XSIDE":
    fig = plt.figure(1, figsize=(8,8))
    fig.clf()
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(elev=0*Z, azim=0)
    ax.set_aspect(0.65)
elif PERSP == "YSIDE":
    fig = plt.figure(1, figsize=(8,8))
    fig.clf()
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(elev=0*Z, azim=270)
    ax.set_aspect(0.65)
elif PERSP == "ISO":
    fig = plt.figure(1, figsize=(8,6))
    fig.clf()
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(elev=1.1*Z, azim=22.5)
else:
    raise Exception("Pick 'XSIDE', 'YSIDE', or 'ISO'")

ax.grid(b=False)
ax.set_axis_off()

#-- Add 3 vectors for nicer axes
xmin=-30;xmax=30;ymin=-30;ymax=30;zmin=-15;zmax=45
xax = Arrow3D([xmin,xmax],[0,0],[0,0],
               mutation_scale=10, lw=1, arrowstyle='->', color="gray",
               alpha=0.5, zorder=0.003)
yax = Arrow3D([0,0],[ymin,ymax],[0,0],
               mutation_scale=10, lw=1, arrowstyle='->', color="gray",
               alpha=0.5, zorder=0.001)
zax = Arrow3D([0,0],[0,0],[zmin,zmax],
               mutation_scale=10, lw=1, arrowstyle='->', color="gray",
               alpha=0.5, zorder=0.002)
ax.add_artist(xax)
ax.add_artist(yax)
ax.add_artist(zax)


origin = ax.plot3D([0],[0],[0],  'o', color='gray', markersize=3, zorder=3)



#-- Add sphere, shaded wireframe
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

x = R * np.outer(np.cos(u), np.sin(v))
y = R * np.outer(np.sin(u), np.sin(v))
z = R * np.outer(np.ones(np.size(u)), np.cos(v))
sph = ax.plot_surface(x, y, z,  rstride=4, cstride=4,
                      color=[0.5]*3, edgecolor=(0,0,0,0.5), alpha=0.1,
                      linewidth=0.1, shade=True, antialiased=True)

#-- Add point at which evaluating E (r)
point = ax.plot3D([0],[0],[Z],  'ro', markersize=5)

chunk = ax.plot_surface([0,1,1,0],[0,0,1,1],[0,0,0,0])

E_x0 = 0
E_y0 = 0
E_z0 = Z

r_x0 = 0
r_y0 = 0
r_z0 = 0

r_x1 = 0
r_y1 = 0
r_z1 = Z


r_vec = Arrow3D([0,r_x1],[0,r_y1],[0,r_z1],
               mutation_scale=20, lw=2, arrowstyle='-|>', color="r", zorder=0.02,
               alpha=0.8)

ri_vec = Arrow3D([0,r_x0],[0,r_y0],[0,r_z0],
               mutation_scale=10, lw=2, arrowstyle='-|>', color="k", zorder=0.8,
               alpha=0.8)

rp_vec = Arrow3D([0,r_x1],[0,r_y1],[0,r_z1],
               mutation_scale=20, lw=2, arrowstyle='-|>', color="b", zorder=0.9,
               alpha=0.8)

#r_pt, = ax.plot3D([r_x0],[r_y0],[r_z0],  'ko', markersize=5)

Ei_color = (0,0.5,0.5)
Ei_vec = Arrow3D([0,0],[0,0],[30,40],
               mutation_scale=15, lw=2, arrowstyle='-|>', color=Ei_color)

polys = polVolDiffelVerts(R-R/20, pi/2, 0, R/10, pi/20, R/10)
#diffVolEl = P3D(polys, linewidth=0.2, facecolor=(1,0.3,0.1), alpha=0.8)
diffVolEl = P3D(polys, linewidth=0.2, facecolor=(1,0.3,0.1), alpha=0.6,zorder=0.015)

polys = polVolDiffelVerts(R-R/2, 0, 0, R, 2*pi, R/10, R/10)
diffDisk = P3D(polys, linewidth=0.05, facecolor=(1,0.3,0.1), alpha=0.1,zorder=0.012)

polys = polVolDiffelVerts(R-R/2, 0, 0, R/8, 2*pi, R/10, R/10)
diffTorus = P3D(polys, linewidth=0.1, facecolor=None, alpha=0.0,zorder=0.013)

ax.add_artist(r_vec)
ax.add_artist(ri_vec)
ax.add_artist(rp_vec)
ax.add_artist(Ei_vec)
ax.add_collection3d(diffDisk)
ax.add_collection3d(diffTorus)
ax.add_collection3d(diffVolEl)

if PERSP == "XSIDE":
    ax.text(0, ymax+1, 0, r"$y$", ha='center', va='center')
    ax.text(0, 0, zmax+1, r"$z$", ha='center', va='center')
    rp_txt = ax.text(0, 2, Z*.75, r"$\vec{{r}}_i=\vec r - \vec r'_i$",
                     size=16, ha='left', va='center', color='b', zorder=1)
    Ei_txt = ax.text(0,0,40, r"$\vec {E_i}$",
                     size=16, ha='center', va='center', color=Ei_color, zorder=1)
    ri_txt = ax.text(2, 1, -1, r"$\vec r'_i$",
                     size=16, ha='left', va='center', color='k', zorder=1)
    r_txt = ax.text(0, 2, Z/2, r"$\vec r$",
                   size=16, ha='center', va='center', color='r', zorder=1)

if PERSP == "YSIDE":
    ax.text(xmax+1, 0, 0, r"$x$", ha='center', va='center')
    ax.text(0, 0, zmax+1, r"$z$", ha='center', va='center')
    rp_txt = ax.text(2, 2, Z*.75, r"$\vec{{r}}_i=\vec r - \vec r'_i$",
                     size=16, ha='left', va='center', color='b', zorder=1)
    Ei_txt = ax.text(0,0,40, r"$\vec {E_i}$",
                     size=16, ha='center', va='center', color=Ei_color, zorder=1)
    ri_txt = ax.text(2, 1, -2, r"$\vec r'_i$",
                     size=16, ha='left', va='center', color='k', zorder=1)
    r_txt = ax.text(2, 2, Z/2, r"$\vec r$",
                   size=16, ha='center', va='center', color='r', zorder=1)

if PERSP == "ISO":
    ax.text(xmax+1, 1, -1, r"$x$", ha='center', va='center')
    ax.text(0, ymax+1, 0, r"$y$", ha='center', va='center')
    ax.text(0, 0, zmax+1, r"$z$", ha='center', va='center')
    rp_txt = ax.text(0, 2, Z*.75, r"$\vec{{r}}_i=\vec r - \vec r'_i$",
                     size=16, ha='left', va='center', color='b', zorder=1)
    Ei_txt = ax.text(0,0,40, r"$\vec {E_i}$",
                     size=16, ha='center', va='center', color=Ei_color, zorder=1)
    ri_txt = ax.text(2, 1, -1, r"$\vec r'_i$",
                     size=16, ha='left', va='center', color='k', zorder=1)
    r_txt = ax.text(0, 2, Z/2, r"$\vec r$",
                   size=16, ha='center', va='center', color='r', zorder=1)

    eqn = ax.text(-10,5,30, 
                  r"$\mathrm{At\,each\,step:}$"
                  +"\n"
                  +r"$\vec{E_i}(\vec{r}) = k\,\frac{\rho(\vec r'_i)\,\mathrm{d}V'_i}{\|\|\vec{{r}}_i\|\|^2}"
                  + r"\,\hat{{r}}_i$",
                  size=16)
    eqn2 = ax.text(10,5,-15,
                   r"$\mathrm{Overall\,operation:}$"
                   +"\n"
                   +r"$\vec{E}(\vec{r}) = "
                   +r"\int_{z'_i=-R}^{R}\,"
                   +r"\int_{\varrho'_i=0}^{\sqrt{R^2-z_i'^2}}"
                   +r"\int_{\theta'_i=0}^{2\pi}"
                   +r"\left( k\,\frac{\rho(\vec r'_i)\,"
                   +r"\left( \varrho'_i \mathrm{d}\theta'_i\,\mathrm{d}\varrho'_i\,\mathrm{d}z'_i \right)"
                   +r"}{\|\|\vec{{r}}_i\|\|^2}"
                   + r"\,\hat{{r}}_i\right)$",
                   ha="center", va="top",
                   size=14)

ax.set_xlim(left=-30,right=30)
ax.set_ylim(bottom=-30, top=30)

thetaStep = pi/4
rStep = R/4

rhoStepTgt = R/5
dsStepTgt = R/5
dzStepTgt = R/10

phiStep = pi/4
plt.show()

nZSamp = max(floor(2*R/dzStepTgt), 1)
zStep = 2*R/nZSamp
#tight_layout()
draw()
show()

# %%
n = 0
for z in np.linspace(-R+zStep/2, R-zStep/2, nZSamp):
    print "z:", z
    rhoMin = 0
    rhoMax = np.sqrt(R**2 - z**2)
    nRhoSamp = max(floor(rhoMax/rhoStepTgt), 1)
    rhoStep = rhoMax/nRhoSamp
    
    #-- Cylindrical wireframe
    polys = polVolDiffelVerts(rhoMax-rhoMax/2, 0, z,  rhoMax, 2*pi, zStep, R/10)
    diffDisk.set_verts(polys)
    

    for rho in np.linspace(rhoMin+rhoStep/2, rhoMax-rhoStep/2, nRhoSamp):
        nPhiSamp = max(floor(2*pi/(dsStepTgt/rho)),1)
        phiStep = 2*pi/nPhiSamp
        
        polys = polVolDiffelVerts(rho, 0, z,  rhoStep, 2*pi, zStep, zStep)
        diffTorus.set_verts(polys)

        for phi in np.linspace(phiStep/2, 2*pi-phiStep/2, nPhiSamp):
            polys = polVolDiffelVerts(rho, phi,z, rhoStep, phiStep, zStep, rhoStep/3)
            diffVolEl.set_verts(polys)

            (r_x0,r_y0) = pol2cart(rho, phi)
            r_z0 = z
            
            D_x = r_x1-r_x0
            D_y = r_y1-r_y0
            D_z = r_z1-r_z0
            
            D_rm3 = 10*Z**2*(D_x**2+D_y**2+D_z**2)**(-3/2)
            
            E_x1 = E_x0 + D_x*D_rm3
            E_y1 = E_y0 + D_y*D_rm3
            E_z1 = E_z0 + D_z*D_rm3

            ri_vec._verts3d = ([0,r_x0],[0,r_y0],[0,r_z0])
            ri_txt.set_position((n*r_x1+1,n*r_y1+1))
            draw()
            
            #rp_txt.set_3d_properties(z=r_z0)
            
            rp_vec._verts3d = ([r_x0,r_x1],[r_y0,r_y1], [r_z0,r_z1])
            #r_pt._verts3d = ([r_x0], [r_y0], [r_z0])
            Ei_vec._verts3d = ([E_x0,E_x1],[E_y0,E_y1],[E_z0,E_z1])
            #chunk.set_verts((chunk_x, chunk_y, chunk_z))
            plt.draw()
            if PERSP == "ISO":
                fig.savefig("frames/frame"+format(n, '04d')+"_iso.png")
            elif PERSP == "XSIDE":
                fig.savefig("frames/frame"+format(n, '04d')+"_xside.png")
            elif PERSP == "YSIDE":
                fig.savefig("frames/frame"+format(n, '04d')+"_yside.png")
            #plt.show()
            n += 1
            time.sleep(0.1)
            #if n == 77:
            #    fig.savefig("frames/frame"+format(n, '04d')+"_iso.pdf")
            #    raise Exception()
# Out:
# z: -9.5
# z:
#  -8.5
# z:
#  -7.5
# z:
#  -6.5
# z:
#  -5.5
# z:
#  -4.5
# z:
#  -3.5
# z:
#  -2.5
# z:
#  -1.5
# z:
#  -0.5
# z:
#  0.5
# z:
#  1.5
# z:
#  2.5
# z:
#  3.5
# z:
#  4.5
# z:
#  5.5
# z:
#  6.5
# z:
#  7.5
# z:
#  8.5
# z:
#  9.5

# %%
close(2)
fig2 = plt.figure(2, figsize=(8,6))
fig2.clf()
ax2 = fig2.add_subplot(111, projection='3d')

n_angles = 30
n_radii = 10
min_radius = 0.0
radii = np.linspace(min_radius, 0.95, n_radii)

angles = np.linspace(0, 2*math.pi, n_angles, endpoint=False)
angles = np.repeat(angles[..., np.newaxis], n_radii, axis=1)
angles[:, 1::2] += math.pi/n_angles

x = (radii*np.cos(angles)).flatten()
y = (radii*np.sin(angles)).flatten()
print x[0:10]
V = np.sqrt(x**2+y**2+0.1)
triang = Triangulation(x,y)
X, Y = np.meshgrid(x, y)

# # Mask off unwanted triangles.
# xmid = x[triang.triangles].mean(axis=1)
# ymid = y[triang.triangles].mean(axis=1)
# mask = np.where(xmid*xmid + ymid*ymid < min_radius*min_radius, 1, 0)
# triang.set_mask(mask)
ax2.plot3D(triang.x, triang.y,'b.') #, np.ones_like(triang.x), facecolors=V/max(V))
ax2.plot_surface(X,Y,np.sin(np.sqrt(X**2+Y**2)))
#ax2.tripcolor(triang) #, np.ones_like(triang.x), facecolors=V/max(V))
draw()
show()
# Out:
# [ 0.          0.10497731  0.21111111  0.31493193  0.42222222  0.52488656
#   0.63333333  0.73484118  0.84444444  0.9447958 ]

# %%
close(2)
fig2 = plt.figure(2, figsize=(8,6))
fig2.clf()
ax2 = fig2.add_subplot(111, projection='3d')
#ax.view_init(elev=1.1*Z, azim=25)
# b_x = [0,1,1,0]
# b_y = [0,0,1,1]
# b_z = [1,1,0,1]
# verts = [zip(b_x, b_y, b_z)]
#verts = [zip(x,y,np.ones_like(x))]
# for poly in polys:
#     ax2.add_collection3d(P3D([poly]))  (b_x,b_y,b_z,cmap=cm.coolwarm, linewidth=1, antialiased=False, color='b',

polys = polVolDiffelVerts(0.1,0,0, 0.2,2*pi,0.1, 0.05)
c = P3D(polys, linewidth=0.2, facecolor=(1,0.3,0.1), alpha=0.8)
ax2.add_collection3d(c)

draw()
show()

# %%
polys = polVolDiffelVerts(0.2,0,0, 0.2,2*pi,0.1, 0.05)
c.set_verts(polys)
draw()

# %%
# %%sh?

# %%
#!/bin/bash

OLDPWD=`pwd`
cd frames

mkdir cropped

for fname in `ls frame*_*side.png | sed 's/\.png//g'`;do
	#echo $fname
	convert ${fname}.png -crop 450x550+190+125 cropped/${fname}_crop.png
done

for fname in `ls frame*_iso.png | sed 's/\.png//g'`;do
    #echo ${fname}
    convert ${fname}.png -crop 500x550+175+25 cropped/${fname}_crop.png
done

for fname in `ls frame*_iso.png | sed 's/_iso\.png//g'`;do 
    #echo $fname
    convert cropped/${fname}_iso_crop.png cropped/${fname}_xside_crop.png cropped/${fname}_yside_crop.png +append cropped/${fname}_cat.png
    #convert cropped/${fname}_iso_crop.png cropped/${fname}_xside_crop.png +append cropped/${fname}_cat.png
done

# #mencoder mf://frames/cropped/frame*_cat.png -lavcopts vcodec=msmpeg4v2:vbitrate=1200 -mf type=png:fps=20 -ovc lavc -o visual_coulomb_integral.avi
mencoder mf://cropped/frame*_cat.png -lavcopts vcodec=msmpeg4v2:vbitrate=1200 -mf type=png:fps=20 -ovc lavc -o visual_coulomb_integral.avi

cd $OLDPWD
# Out:
# MEncoder svn r34540 (Ubuntu), built with gcc-4.7 (C) 2000-2012 MPlayer Team
# success: format: 16  data: 0x0 - 0x0
# MF file format detected.
# [mf] search expr: cropped/frame*_cat.png
# [mf] number of files: 846 (6768)
# VIDEO:  [MPNG]  0x0  24bpp  20.000 fps    0.0 kbps ( 0.0 kbyte/s)
# [V] filefmt:16  fourcc:0x474E504D  size:0x0  fps:20.000  ftime:=0.0500
# libavcodec version 53.35.0 (external)
# Mismatching header version 53.32.2
# Opening video filter: [expand osd=1]
# Expand: -1 x -1, -1 ; -1, osd: 1, aspect: 0.000000, round: 1
# ==========================================================================
# Opening video decoder: [ffmpeg] FFmpeg's libavcodec codec family
# Selected video codec: [ffpng] vfm: ffmpeg (FFmpeg PNG)
# ==========================================================================
# Could not find matching colorspace - retrying with -vf scale...
# Opening video filter: [scale]
# Movie-Aspect is undefined - no prescaling applied.
# [swscaler @ 0x7fe4b02460e0]BICUBIC scaler, from bgra to yuv420p using MMX2
# videocodec: libavcodec (1400x550 fourcc=3234504d [MP42])
# Writing header...
# ODML: Aspect information not (yet?) available or unspecified, not writing vprp header.
# Writing header...
# ODML: Aspect information not (yet?) available or unspecified, not writing vprp header.
# Pos:   0.1s      2f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   0.2s      4f ( 0%)  3.88fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 2 dct coefficients to -127..127
# Pos:   0.2s      5f ( 0%)  4.73fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   0.3s      6f ( 0%)  5.56fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   0.4s      8f ( 0%)  7.19fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   0.5s      9f ( 1%)  7.97fps Trem:   1min  11mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   0.8s     15f ( 1%) 12.06fps Trem:   2min  15mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   1.4s     29f ( 3%) 17.90fps Trem:   0min   8mb  A-V:0.000 [1374:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   1.6s     31f ( 3%) 18.43fps Trem:   0min   8mb  A-V:0.000 [1354:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   1.8s     36f ( 4%) 19.54fps Trem:   0min   7mb  A-V:0.000 [1340:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   2.2s     44f ( 5%) 20.85fps Trem:   0min   6mb  A-V:0.000 [1301:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   2.3s     46f ( 5%) 20.99fps Trem:   0min   7mb  A-V:0.000 [1293:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   2.9s     57f ( 6%) 24.11fps Trem:   0min   7mb  A-V:0.000 [1264:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   3.4s     67f ( 7%) 26.49fps Trem:   0min   7mb  A-V:0.000 [1251:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   3.5s     70f ( 8%) 27.11fps Trem:   0min   6mb  A-V:0.000 [1249:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   4.1s     82f ( 9%) 29.53fps Trem:   0min   6mb  A-V:0.000 [1226:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   4.8s     95f (11%) 31.74fps Trem:   0min   6mb  A-V:0.000 [1212:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   5.0s    100f (11%) 32.56fps Trem:   0min   6mb  A-V:0.000 [1212:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   5.7s    114f (13%) 34.58fps Trem:   0min   6mb  A-V:0.000 [1197:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   7.1s    142f (16%) 38.12fps Trem:   0min   6mb  A-V:0.000 [1178:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   7.2s    143f (16%) 38.23fps Trem:   0min   6mb  A-V:0.000 [1177:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   7.2s    144f (17%) 38.34fps Trem:   0min   5mb  A-V:0.000 [1175:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   7.5s    150f (17%) 38.98fps Trem:   0min   6mb  A-V:0.000 [1175:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   8.2s    164f (19%) 40.37fps Trem:   0min   6mb  A-V:0.000 [1166:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   8.3s    166f (19%) 40.56fps Trem:   0min   6mb  A-V:0.000 [1168:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   8.5s    170f (20%) 40.91fps Trem:   0min   5mb  A-V:0.000 [1168:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   8.8s    176f (20%) 41.45fps Trem:   0min   6mb  A-V:0.000 [1164:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   9.0s    180f (21%) 41.78fps Trem:   0min   5mb  A-V:0.000 [1162:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   9.3s    186f (22%) 42.23fps Trem:   0min   5mb  A-V:0.000 [1157:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:   9.7s    194f (22%) 42.86fps Trem:   0min   6mb  A-V:0.000 [1158:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  11.1s    222f (26%) 44.77fps Trem:   0min   5mb  A-V:0.000 [1150:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  11.2s    225f (26%) 44.95fps Trem:   0min   5mb  A-V:0.000 [1152:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  12.2s    244f (28%) 46.02fps Trem:   0min   5mb  A-V:0.000 [1146:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  12.6s    251f (29%) 46.39fps Trem:   0min   6mb  A-V:0.000 [1175:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  13.1s    261f (30%) 46.90fps Trem:   0min   6mb  A-V:0.000 [1171:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  13.2s    264f (31%) 47.06fps Trem:   0min   5mb  A-V:0.000 [1170:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  14.0s    280f (33%) 47.79fps Trem:   0min   5mb  A-V:0.000 [1165:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  14.2s    285f (33%) 48.01fps Trem:   0min   6mb  A-V:0.000 [1165:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  14.6s    291f (34%) 48.27fps Trem:   0min   5mb  A-V:0.000 [1163:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  15.5s    310f (36%) 49.04fps Trem:   0min   5mb  A-V:0.000 [1158:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  16.1s    323f (38%) 49.48fps Trem:   0min   5mb  A-V:0.000 [1153:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  17.2s    344f (40%) 50.15fps Trem:   0min   5mb  A-V:0.000 [1149:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  18.4s    368f (43%) 50.86fps Trem:   0min   5mb  A-V:0.000 [1142:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  18.5s    370f (43%) 50.90fps Trem:   0min   5mb  A-V:0.000 [1141:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  19.1s    383f (45%) 51.26fps Trem:   0min   5mb  A-V:0.000 [1138:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  19.9s    399f (47%) 51.66fps Trem:   0min   5mb  A-V:0.000 [1135:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  20.2s    404f (47%) 51.77fps Trem:   0min   5mb  A-V:0.000 [1135:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  21.4s    428f (50%) 52.28fps Trem:   0min   5mb  A-V:0.000 [1130:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  21.5s    430f (50%) 52.33fps Trem:   0min   5mb  A-V:0.000 [1129:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  22.1s    443f (52%) 52.61fps Trem:   0min   5mb  A-V:0.000 [1128:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  22.5s    450f (52%) 52.76fps Trem:   0min   5mb  A-V:0.000 [1126:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  22.8s    456f (52%) 52.88fps Trem:   0min   5mb  A-V:0.000 [1123:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  22.9s    459f (54%) 52.94fps Trem:   0min   5mb  A-V:0.000 [1125:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  23.2s    464f (54%) 53.04fps Trem:   0min   5mb  A-V:0.000 [1125:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  24.4s    488f (57%) 53.49fps Trem:   0min   5mb  A-V:0.000 [1121:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  24.5s    490f (57%) 53.52fps Trem:   0min   5mb  A-V:0.000 [1120:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  25.9s    519f (61%) 53.97fps Trem:   0min   5mb  A-V:0.000 [1130:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  26.2s    524f (62%) 54.05fps Trem:   0min   5mb  A-V:0.000 [1130:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  27.4s    548f (64%) 54.41fps Trem:   0min   5mb  A-V:0.000 [1127:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  27.5s    550f (65%) 54.43fps Trem:   0min   5mb  A-V:0.000 [1126:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  28.0s    560f (66%) 54.58fps Trem:   0min   5mb  A-V:0.000 [1126:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  28.1s    563f (66%) 54.62fps Trem:   0min   5mb  A-V:0.000 [1126:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  28.9s    579f (68%) 54.85fps Trem:   0min   5mb  A-V:0.000 [1125:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  30.4s    607f (71%) 55.23fps Trem:   0min   5mb  A-V:0.000 [1124:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  30.4s    609f (72%) 55.26fps Trem:   0min   5mb  A-V:0.000 [1124:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  30.5s    610f (72%) 55.27fps Trem:   0min   5mb  A-V:0.000 [1124:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  30.9s    619f (73%) 55.39fps Trem:   0min   5mb  A-V:0.000 [1124:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  31.9s    637f (75%) 55.60fps Trem:   0min   5mb  A-V:0.000 [1124:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  33.2s    664f (78%) 55.91fps Trem:   0min   5mb  A-V:0.000 [1125:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  34.3s    686f (81%) 56.10fps Trem:   0min   5mb  A-V:0.000 [1125:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  34.6s    692f (81%) 56.15fps Trem:   0min   5mb  A-V:0.000 [1126:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  35.3s    706f (83%) 56.29fps Trem:   0min   5mb  A-V:0.000 [1125:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  35.4s    707f (83%) 56.30fps Trem:   0min   5mb  A-V:0.000 [1125:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  36.0s    720f (85%) 56.44fps Trem:   0min   5mb  A-V:0.000 [1126:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  37.0s    741f (87%) 56.64fps Trem:   0min   5mb  A-V:0.000 [1127:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  37.2s    744f (88%) 56.67fps Trem:   0min   5mb  A-V:0.000 [1128:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  37.3s    746f (88%) 56.68fps Trem:   0min   5mb  A-V:0.000 [1129:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  38.1s    763f (90%) 56.83fps Trem:   0min   5mb  A-V:0.000 [1137:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  38.4s    768f (90%) 56.86fps Trem:   0min   5mb  A-V:0.000 [1139:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  38.5s    770f (91%) 56.89fps Trem:   0min   5mb  A-V:0.000 [1139:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  38.9s    777f (91%) 56.95fps Trem:   0min   5mb  A-V:0.000 [1139:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  40.0s    801f (94%) 57.15fps Trem:   0min   5mb  A-V:0.000 [1142:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  41.6s    832f (98%) 57.38fps Trem:   0min   5mb  A-V:0.000 [1144:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  41.9s    838f (99%) 57.42fps Trem:   0min   5mb  A-V:0.000 [1144:0]
# [msmpeg4v2 @ 0x7fe4af764340]warning, clipping 1 dct coefficients to -127..127
# Pos:  42.3s    846f (100%) 57.49fps Trem:   0min   5mb  A-V:0.000 [1144:0]
#
# Flushing video frames.
# Writing index...
# Writing header...
# ODML: Aspect information not (yet?) available or unspecified, not writing vprp header.
#
# Video stream: 1144.637 kbit/s  (143079 B/s)  size: 6052269 bytes  42.300 secs  846 frames
# [VD_FFMPEG] DRI failure.

# %%
pwd
# Out:
# u'/home/justin/courses/TA/teaching_materials/visualizing_integrating_coulombs_law'
